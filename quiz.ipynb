# %% [markdown]
# <img align="right" width="125" src="https://www.ou.nl/documents/40554/3255217/Logo_OU.jpg"/>
#
# <br>
#
#
# <center> <font size ="6" color='red'> OU CPP Lab Tool </font></center>
# <br>
#
# <br>

# %%
online_version = False
import os
from IPython.display import clear_output
if online_version:
    if os.path.basename(os.getcwd()) != "CPP_LAB_Tool":
        # !git clone https://github.com/muratfirat78/CPP_LAB_Tool >/dev/null 2>&1
        # %cd CPP_LAB_Tool
        #@title Quiz

from IPython.display import display
from VisualManager import VisualManager

if online_version:
    from google.colab import auth
    auth.authenticate_user()
    from GoogleDrive import GoogleDrive
    drive = GoogleDrive()
else:
    from LocalDrive import GoogleDrive
    drive = GoogleDrive()
clear_output()
VisMgr = VisualManager(drive, online_version)

display(VisMgr.get_ui())

# %%
import pandas as pd

def DataRead(myurl):
    df = pd.read_csv(myurl)
    return df.isnull().sum().sum()
