# %%
online_version = False
import os
from IPython.display import clear_output
if online_version:
    if os.path.basename(os.getcwd()) != "CPP_LAB_Tool":
        # !git clone https://github.com/muratfirat78/CPP_LAB_Tool >/dev/null 2>&1
        # %cd CPP_LAB_Tool
        #@title Quiz

from IPython.display import display
from Controller import Controller

if online_version:
    from google.colab import auth
    auth.authenticate_user()
    from GoogleDrive import GoogleDrive
    drive = GoogleDrive()
else:
    from LocalDrive import GoogleDrive
    drive = GoogleDrive()
clear_output()
controller = Controller(drive, online_version)
controller.start()
# Out:
# VBox(children=(VBox(children=(Dropdown(description='Component:', options=('Data Understanding And Data Prepara…

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)

result = {
    "total_missing_values": 1,
    "num_rows": len(df)
}

print(result)
# Out:
# {'total_missing_values': 869, 'num_rows': 891}
